# %% [markdown]
# # Assignment 1 - Data Wrangling I

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Importing CSV
df = pd.read_csv("StudentsPerformance_modified.csv")

# %%
# Displaying CSV Imported
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course math score  reading score  writing score
# 0                      none         72           72.0           74.0
# ...

# %%
# Displaying info about CSV
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   992 non-null    object
#  6   reading score                994 non-null    float64
#  7   writing score                991 non-null    float64
# dtypes: float64(2), object(6)
# memory usage: 62.6+ KB

# %%
# Dimensions of CSV
df.shape
# Out:
# (1000, 8)

# %%
# Statistics of CSV
df.describe()
# Out:
#        reading score  writing score
# count     994.000000     991.000000
# mean       68.008048      69.487386
# std        16.602270      29.563757
# min         3.000000      10.000000
# 25%        58.000000      57.000000
# 50%        69.500000      69.000000
# 75%        79.000000      79.000000
# max       100.000000     567.000000

# %%
# Datatypes of each column
df.dtypes
# Out:
# gender                          object
# race/ethnicity                  object
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                      object
# reading score                  float64
# writing score                  float64
# dtype: object

# %%
# Creating Copy of DataFrame
df1 = df.copy()

# %%
# Checking Null values in each column
df1.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     8
# reading score                  6
# writing score                  9
# dtype: int64

# %%
# Displaying Count of Null Values
df1.isnull().sum().sum()
# Out:
# 23

# %%
# Percentage of Null Values
(df1.isnull().sum().sum()/(df1.shape[0]*df1.shape[1]))*100
# Out:
# 0.2875

# %%
sns.heatmap(df1.isnull())
plt.show()

# %%
# Drop rows having null values for any column
df1 = df1.dropna()

# Other Methods of Handling Missing Values

# 1. Mode Filling
# df1["math score"].fillna(df1["math score"].mode()[0], inplace=True);
# df1["reading score"].fillna(df1["reading score"].mode()[0], inplace=True);
# df1["writing score"].fillna(df1["writing score"].mode()[0], inplace=True);

# 2. Backward Filling
# df1["math score"].fillna(method="bfill", inplace=True);
# df1["reading score"].fillna(method="bfill", inplace=True);
# df1["writing score"].fillna(method="bfill", inplace=True);

# 3. Forward Filling
# df1["math score"].fillna(method="ffill", inplace=True);
# df1["reading score"].fillna(method="ffill", inplace=True);
# df1["writing score"].fillna(method="ffill", inplace=True);

df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course math score  reading score  writing score
# 0                      none         72           72.0           74.0
# ...

# %%
# Dimensions after dropping rows with null values
df1.shape
# Out:
# (978, 8)

# %%
# Checking Null values in each column after dropping rows
df1.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
# Datatype of Math Score column
df1["math score"].dtype
# Out:
# dtype('O')

# %%
# Rows with value of math score as "?"
df1[df1["math score"] == "?"]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 432    male        group C                 high school      standard
# 433  female        group A            some high school  free/reduced
# 434    male        group C            some high school      standard
# 435    male        group C                some college  free/reduced
# 436    male        group D          associate's degree      standard
# 437    male        group D          associate's degree  free/reduced
# 438    male        group C                 high school      standard
# 439    male        group D            some high school      standard
# 440  female        group C                some college      standard
# 441  female        group D                 high school      standard
# 442  female        group A            some high school  free/reduced
# 443  female        group B          associate's degree      standard
# 444    male        group A            some high school  free/reduced
# ...

# %%
# Dropping rows which has value of math score as "?"
df1 = df1.drop(df1[df1["math score"] == "?"].index);

# %%
# Changing datatype of math score column to integer
df1["math score"] = df1["math score"].astype("int64")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 943 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       943 non-null    object
#  1   race/ethnicity               943 non-null    object
#  2   parental level of education  943 non-null    object
#  3   lunch                        943 non-null    object
#  4   test preparation course      943 non-null    object
#  5   math score                   943 non-null    int64
#  6   reading score                943 non-null    float64
#  7   writing score                943 non-null    float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 66.3+ KB

# %%
# Rows with value of math score as negative
df1[df1["math score"] < 0]
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 456  female        group D           bachelor's degree  standard
#
#     test preparation course  math score  reading score  writing score
# 456                    none         -89           89.0           89.0

# %%
# Dropping rows which has value of math score as negative
df1 = df1.drop(df1[df1["math score"] < 0].index);

# %%
# Dimensions after dropping 
df1.shape
# Out:
# (942, 8)

# %%
# Creating copy of df1
df2 = df1.copy()

# %%
df["gender"].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
# Converting Categorical Variables to Numerical Variables 

# Label Encoding
df2["gender"] = df2["gender"].astype("category").cat.codes
df2["race/ethnicity"] = df2["race/ethnicity"].astype("category").cat.codes
df2["parental level of education"] = df2["parental level of education"].astype("category").cat.codes
df2["lunch"] = df2["lunch"].astype("category").cat.codes
df2["test preparation course"] = df2["test preparation course"].astype("category").cat.codes

# Label Encoding using scikit-learn
# from sklearn.preprocessing import LabelEncoder
# le = LabelEncoder()
# df2["gender"] = le.fit_transform(df2["gender"])
# df2["race/ethnicity"] = le.fit_transform(df2["race/ethnicity"])
# df2["parental level of education"] = le.fit_transform(df2["parental level of education"])
# df2["lunch"] = le.fit_transform(df2["lunch"])
# df2["test preparation course"] = le.fit_transform(df2["test preparation course"])

# One Hot Encoding 
# df2 = pd.get_dummies(data=df2, columns=["gender", "race/ethnicity", "parental level of education", "lunch", "test preparation course"])

# %%
df2
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0         0               1                            1      1
# 1         0               2                            4      1
# 2         0               1                            3      1
# 3         1               0                            0      0
# 4         1               2                            4      1
# ..      ...             ...                          ...    ...
# 995       0               4                            3      1
# 996       1               2                            2      0
# 997       0               2                            2      0
# 998       0               3                            4      1
# 999       0               3                            4      0
#
#      test preparation course  math score  reading score  writing score
# 0                          1          72           72.0           74.0
# ...

# %%
df3 = df2.copy()

# %%
# Normalization
columns = ["math score", "reading score", "writing score"]


# 1. Min-Max Normalization - It rescales the values of a numerical variable to a fixed range, typically between 0 and 1
for column in columns:
    df3[column] = (df3[column]-df3[column].min())/(df3[column].max()-df3[column].min())

# Using scikit-learn
# from sklearn.preprocessing import MinMaxScaler 
# ms = MinMaxScaler()
# for column in columns:
#     df3[column] = ms.fit_transform(df3[[column]])


# 2. Z-score Normalization (Standardization) - It transforms the values of a numerical variable to have a mean of 0 and a standard deviation of 1
# for column in columns:
#     df3[column] = (df3[column]-df3[column].mean())/df3[column].std()

# Using scikit-learn
# from sklearn.preprocessing import StandardScaler 
# ss = StandardScaler()
# for column in columns:
#     df3[column] = ss.fit_transform(df3[[column]])

# %%
df3
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0         0               1                            1      1
# 1         0               2                            4      1
# 2         0               1                            3      1
# 3         1               0                            0      0
# 4         1               2                            4      1
# ..      ...             ...                          ...    ...
# 995       0               4                            3      1
# 996       1               2                            2      0
# 997       0               2                            2      0
# 998       0               3                            4      1
# 999       0               3                            4      0
#
#      test preparation course  math score  reading score  writing score
# 0                          1    0.215569       0.711340       0.114901
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 942 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       942 non-null    int8
#  1   race/ethnicity               942 non-null    int8
#  2   parental level of education  942 non-null    int8
#  3   lunch                        942 non-null    int8
#  4   test preparation course      942 non-null    int8
#  5   math score                   942 non-null    float64
#  6   reading score                942 non-null    float64
#  7   writing score                942 non-null    float64
# dtypes: float64(3), int8(5)
# memory usage: 34.0 KB

# %%
# Statistics for each column
df3.describe()
# Out:
#            gender  race/ethnicity  parental level of education       lunch  \
# count  942.000000      942.000000                   942.000000  942.000000
# mean     0.480892        2.174098                     2.486200    0.649682
# std      0.499900        1.163311                     1.829421    0.477323
# min      0.000000        0.000000                     0.000000    0.000000
# 25%      0.000000        1.000000                     1.000000    0.000000
# 50%      0.000000        2.000000                     2.000000    1.000000
# 75%      1.000000        3.000000                     4.000000    1.000000
# max      1.000000        4.000000                     5.000000    1.000000
#
#        test preparation course  math score  reading score  writing score
# count               942.000000  942.000000     942.000000     942.000000
# mean                  0.639066    0.198921       0.674929       0.107055
# std                   0.480527    0.052898       0.164834       0.054084
# ...

# %%
# Exporting the processed csv
df3.to_csv("result.csv")
